# %% [markdown]
# # Load Data from Database Using SQL

# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
# Connect to sqlite db
db_file = r'datasets/database.sqlite'
engine = create_engine(r"sqlite:///{}".format(db_file))

# %%
#find out what tables are in the database
sql = "SELECT name FROM sqlite_master WHERE type = 'table';"

table_names = pd.read_sql(sql, engine)
table_names
# Out:
#                        name
# 0                BoardGames
# 1         bgg.ldaOut.topics
# 2      bgg.ldaOut.top.terms
# 3  bgg.ldaOut.top.documents
# 4                bgg.topics

# %%
#get all the rows from the "test" table in the database
sql = "SELECT * FROM BoardGames;"
sales_data_df = pd.read_sql(sql, engine)
sales_data_df
# Out:
#       row_names game.id           game.type  \
# 0             1       1           boardgame
# 1             2       2           boardgame
# 2             3       3           boardgame
# 3             4       4           boardgame
# 4             5       5           boardgame
# 5             6       6           boardgame
# 6             7       7           boardgame
# 7             8       8           boardgame
# 8             9       9           boardgame
# 9            10      10           boardgame
# 10           11      11           boardgame
# 11           12      12           boardgame
# 12           13      13           boardgame
# 13           14      14           boardgame
# 14           15      15           boardgame
# 15           16      16           boardgame
# 16           17      17           boardgame
# 17           18      18           boardgame
# 18           19      19           boardgame
# 19           20      20           boardgame
# ...

# %%
#get all the rows from the "BoardGames" table in the database
sql = "SELECT * FROM BoardGames;"
BoardGames_data_df = pd.read_sql(sql, engine)
BoardGames_data_df

#get all the rows from the "bgg.IdaOut.top.terms" table in the database
sql = "SELECT * FROM [bgg.IdaOut.top.terms];"
bgg.IdaOut.top.terms_data_df = pd.read_sql(sql, engine)
bgg.IdaOut.top.terms_data_df

#get all the rows from the "bgg.IdaOut.top.terms" table in the database
sql = "SELECT * FROM [bgg.IdaOut.top.terms];"
bgg.IdaOut.top.terms_data_df = pd.read_sql(sql, engine)
bgg.IdaOut.top.terms_data_df

#get all the rows from the "bgg.IdaOut.top.terms" table in the database
sql = "SELECT * FROM [bgg.IdaOut.top.documents];" #Because of '.' the dots present it is necessarry to surround the term with '[]' or "" quatation marks.
bgg.IdaOut.top.documents_data_df = pd.read_sql(sql, engine)
bgg.IdaOut.top.document_data_df

#get all the rows from the "bgg.topics" table in the database
sql = "SELECT * FROM [bgg.topics];"
bgg.topics_data_df = pd.read_sql(sql, engine)
bgg.topics_data_df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# OperationalError: no such table: bgg.IdaOut.top.terms
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-48-373da70ecf38> in <module>()
# ...

# %%
#get all the rows from the "BoardGames" table in the database
sql = "SELECT * FROM BoardGames;"
BoardGames_data_df = pd.read_sql(sql, engine)
BoardGames_data_df

# %%
#get all the rows from the "bgg.IdaOut.top.terms" table in the database
sql = "SELECT * FROM [bgg.ldaOut.topics];"
bgg_terms_data_df = pd.read_sql(sql, engine)
bgg_terms_data_df

# %%
#get all the rows from the "bgg.IdaOut.top.terms" table in the database
sql = "SELECT * FROM [bgg.ldaOut.top.terms];"
bgg_terms_data_df = pd.read_sql(sql, engine)
bgg_terms_data_df

# %%
#get all the rows from the "bgg.IdaOut.top.terms" table in the database
sql = "SELECT * FROM [bgg.ldaOut.top.documents];" #Because of '.' the dots present it is necessarry to surround the term with '[]' or "" quatation marks.
bgg_document_data_df = pd.read_sql(sql, engine)
bgg_document_data_df
# Out:
#     row_names                                           document  topic  \
# 0           1                           The.Lounge..A.Mafia.Game      1
# 1           2                Ultimate.Werewolf..Ultimate.Edition      1
# 2           3  Ultimate.Werewolf..Deluxe.Edition.For.Kickstarter      1
# 3           4                                           Werewolf      1
# 4           5                     Παλέρμο..Το.Μεγάλο.Ξεκαθάρισμα      1
# 5           6                Ultimate.Werewolf..Whitebox.Edition      1
# 6           7                                  Una.Notte.da.Lupi      1
# 7           8                                    Mafia..Vendetta      1
# 8           9        The.Werewolves.of.Miller.s.Hollow..The.Pact      1
# 9          10                  Ultimate.Werewolf..Deluxe.Edition      1
# 10         11                                      Titan.Legions      2
# 11         12                             De.Bellis.Antiquitatis      2
# ...

# %%
#get all the rows from the "bgg.topics" table in the database
sql = "SELECT * FROM [bgg.topics];"
bgg_topics_data_df = pd.read_sql(sql, engine)
bgg_topics_data_df
# Out:
#       row_names game.id  game.type  details.maxplayers  details.maxplaytime  \
# 0             1       1  boardgame                 5.0                240.0
# 1             2       2  boardgame                 4.0                 30.0
# 2             3       3  boardgame                 4.0                 60.0
# 3             4       4  boardgame                 4.0                 60.0
# 4             5       5  boardgame                 6.0                 90.0
# 5             6       6  boardgame                 6.0                240.0
# 6             7       7  boardgame                 2.0                 20.0
# 7             8       8  boardgame                 5.0                120.0
# 8             9       9  boardgame                 4.0                 90.0
# 9            10      10  boardgame                 6.0                 60.0
# 10           11      11  boardgame                 7.0                 45.0
# ...

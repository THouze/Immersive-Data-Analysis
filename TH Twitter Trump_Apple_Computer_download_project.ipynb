# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = 'P7r'
consumer_secret = 'BCBpZtJ0swI2'

access_token = '11gyn'
access_token_secret = 'Su01u2f35'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.search('Trump')

for tweet in public_tweets:
	print(tweet.text)
	analysis = TextBlob(tweet.text)
	print(analysis.sentiment)
# Out:
# RT @funder: BREAKING: Today Trump’s at Mar-a-Lago, making it the 244th day he’s spent at one of his properties since Russia helped elect hi…
# Sentiment(polarity=0.35000000000000003, subjectivity=0.5)
# RT @EmmaMAshford: My only Mueller report twitter take-away: Trump appears to have failed in obstructing justice only because advisors refus…
# Sentiment(polarity=-0.16666666666666666, subjectivity=0.7666666666666666)
# RT @Education4Libs: Freshman representatives Rashida Tlaib, Ilhan Omar &amp; Ocasio-Cortez are trying to impeach President Trump.
#
# Lmao.... for…
# Sentiment(polarity=0.6, subjectivity=1.0)
# RT @EAristeguieta: 38 años de carcel y 148 latigazos es la condena para una abogada iraní, por defender los derechos de la mujer. Quiero oí…
# Sentiment(polarity=0.0, subjectivity=0.0)
# RT @TheoEvan1: First impressions from reading excerpts from the #MuellerReport - Don McGahn apparently saved Trump’s presidency, and said s…
# ...

# %%
consumer_key = 'PJSO3x7r'
consumer_secret = 'BCBpbL5J0swI2'

access_token = '11185fGEgyn'
access_token_secret = 'Su01uvUmfA35'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

#ptweets = api.search('Artificial Intelligence', count=200)

public_tweets = api.search('Apple Computer', count=1000)

for tweet in public_tweets:
	print(tweet.text)
    
	analysis = TextBlob(tweet.text)
	print(analysis.sentiment)
	print('')
# Out:
# RT @DavidBazo: "Time Traveller", A Time Trilogy by @DavidBazo, CD+Computer App!
# 👉Out Now:
# iTunes: https://t.co/hSVHwBkQS1
# Spotify: https://…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# You don’t need a computer science degree to run Google or Facebook, says former Google CEO Eric S... https://t.co/biSmB2HO3l
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# #knownews #tech #techradar Best Mac apps: the best macOS apps for your Apple computer https://t.co/POD7K1VTpB https://t.co/zfasXqMTN5
# Sentiment(polarity=1.0, subjectivity=0.3)
#
# 📢 El archivo secreto que revela por qué Steve Jobs eligió llamar ‘Apple Computer’ a su compañía de informática… https://t.co/DOSETCoAY6
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Best Mac apps: the best macOS apps for your Apple computer https://t.co/LwXkqdV8lE
# Sentiment(polarity=1.0, subjectivity=0.3)
#
# ...
